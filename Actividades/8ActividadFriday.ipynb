# %% [markdown]
# #### Numero de cores...

# %%
import os, multiprocessing as mp, numpy as np

# %%
os.cpu_count()
# Out:
# 4

# %%
A=[[1,2],
   [3,4],
   [5,6],
   [7,8]]

B=[[1,2,3],
   [4,5,6]]

# %%
def multiply(a, b):
    result = [[],[]]
    result[0][0]= a[0][0]*b[0][0]+a[0][1]*b[1][0]
    result[1][0]= a[1][0]*b[0][0]+a[1][1]*b[1][0]
    result[2][0]= a[2][0]*b[0][0]+a[2][1]*b[1][0]
    result[3][0]= a[3][0]*b[0][0]+a[3][1]*b[1][0]
    
    result[0][1]= a[0][0]*b[0][1]+a[0][1]*b[1][1]
    result[1][1]= a[1][0]*b[0][1]+a[1][1]*b[1][1]
    result[2][1]= a[2][0]*b[0][1]+a[2][1]*b[1][1]
    result[3][1]= a[3][0]*b[0][1]+a[3][1]*b[1][1]
    
    result[0][2]= a[0][0]*b[0][2]+a[0][1]*b[1][2]
    result[1][2]= a[1][0]*b[0][2]+a[1][1]*b[1][2]
    result[2][2]= a[2][0]*b[0][2]+a[2][1]*b[1][2]
    result[3][2]= a[3][0]*b[0][2]+a[3][1]*b[1][2]
    return result

# %%
multiply(A,B)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-744e89d8f4d5> in <module>
# ----> 1 multiply(A,B)
#
# <ipython-input-73-1caec87f8bcc> in multiply(a, b)
#       1 def multiply(a, b):
#       2     result = [[],[]]
# ----> 3     result[0][0]= a[0][0]*b[0][0]+a[0][1]*b[1][0]
#       4     result[1][0]= a[1][0]*b[0][0]+a[1][1]*b[1][0]
#       5     result[2][0]= a[2][0]*b[0][0]+a[2][1]*b[1][0]
#
# IndexError: list assignment index out of range
