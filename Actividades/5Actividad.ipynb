# %%
import threading as th, os, platform, requests, concurrent.futures as ct, time, urllib.request as rq, IPython as IP

# %%
def descargar_video():
    imagen = requests.get(url_imagen)

# %%
todos=[]

# %%
for i in range(10):
    url_imagen = "https://storage.googleapis.com/christian_vladimir_sucuzhanay_bucket/pictures_videos/pic00"+str(i)+".jpeg"
    todos.append(url_imagen)

# %%
def descargar_():
    print(todos)

# %%
for j in range(1000):
    threading.Thread(target=descargar_()).start()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4715ac6b1933> in <module>
#       1 for j in range(1000):
# ----> 2     threading.Thread(target=descargar_()).start()
#
# NameError: name 'threading' is not defined
